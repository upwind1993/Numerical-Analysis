# %% [markdown]
# <a href="https://colab.research.google.com/github/upwind1993/Numerical-Analysis/blob/main/6%EC%9E%A5/%EC%97%B0%EC%8A%B5%EB%AC%B8%EC%A0%9C6_17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# (a)  Let’s look at a plot first to find the range for  .

# %%
import numpy as np

w = 10
y0 = 5
y = 15
x = 50

def f(TA):
    return y-(TA/w*np.cosh(w/TA*x)+y0-TA/w)

TAtest = np.linspace(800,2000)
import pylab
pylab.plot(TAtest,f(TAtest),c='k')
pylab.grid()

# %% [markdown]
# Root is backeted by 1200 and 1300.

# %%
import numpy as np

w = 10
y0 = 5
y = 15
x = 50

def f(TA):
    return y-(TA/w*np.cosh(w/TA*x)+y0-TA/w)

from scipy.optimize import brentq

TAsoln = brentq(f,1200,1300)
print('TA = {0:7.1f}'.format(TAsoln))

TA =  1266.3
# Out:
# TA =  1266.3

# %% [markdown]
# (b)	Use the   value from (a) for the plot

# %%
import numpy as np
w = 10
y0 = 5
y = 15
x = 50

def f(TA):
    return y-(TA/w*np.cosh(w/TA*x)+y0-TA/w)

from scipy.optimize import brentq

TA = brentq(f,1200,1300)

def g(x):
    return TA/w*np.cosh(w/TA*x)+y0-TA/w

x = np.linspace(-150,100,100)
import pylab
pylab.plot(x,g(x),c='k')
pylab.grid()
pylab.xlabel('x')
pylab.ylabel('y')
# Out:
# Text(0, 0.5, 'y')
